# %% [markdown]
# <a href="https://colab.research.google.com/github/diego-sc11/Probabilidad/blob/main/Unidad4/U4_Problema1_Poisson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
# ##Unidad 4
# ###Facilitador: Jose Gabriel Rodriguez Rivas
# ###Alumno: Diego Rodriguez Rochin
# ##Problema distribucion poisson
# ##Problema1

# %% [markdown]
# ##Realizar un programa en Python que resuelva el siguiente problema:
# * El número x de, personas ingresadas a una unidad de cuidados intensivos en un hospital particular en un día, tiene una
# distribución de, probabilidad de Poisson con media igual a cinco personas por día.
#
# * a) ¿Cuál es la probabilidad de, que el número de personas ingresadas a una unidad de cuidadlos intensivos en un hospital particular, en un día particular, sea dos?
# * b) ¿Es probable, que x exceda de 10? Explicar

# %% [markdown]
# ###Es de tipo poisson porque no tiene un numero de ensayos fijo

# %%
import math
from scipy.stats import poisson

# Parámetro
media_personas = 5

# Probabilidad de exactamente 2 personas en un dia
probabilidad_2p_ingredsadas = poisson.pmf(2, media_personas)
print("Probabilidad de exactamente 2 personas:", probabilidad_2p_ingredsadas)

# Probabilidad de que X sea mayor a 10
probabilidad_mayor_10 = 1 - poisson.cdf(10, media_personas)
print("Probabilidad de que x sea mayor a 10",probabilidad_mayor_10)
# Out:
# Probabilidad de exactamente 2 personas: 0.08422433748856832
# Probabilidad de que x sea mayor a 10 0.013695268598382881

# %% [markdown]
# ##No es probable que lleguen mas de 10 personas en un dia, es de aproximadamente 1.36%
