# %% [markdown]
# <a href="https://colab.research.google.com/github/diego-sc11/Probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# #**Practica 3: Tabla de frecuencias**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Diego Rodriguez Rochin

# %%
#creamos una lista vacia que representa la edad de 100 personas
import random
edades = []
#Hacemos un ciclo para generar 100 numeros aleatoreos que representen la edad de las personas
for i in range (100):
  # generamos un numero aleatorio con la con la funcion randint y lo guardamos en la vaiable
  # numero aleatorio
  numero_aleatorio = random.randint(18,70)
  # Agregamos el numero aleatorio a la lista de variables
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [35, 44, 27, 21, 65, 49, 64, 45, 32, 63, 64, 62, 20, 66, 43, 65, 21, 24, 31, 26, 41, 51, 37, 43, 38, 30, 54, 70, 61, 61, 54, 19, 64, 68, 37, 59, 54, 51, 52, 34, 31, 30, 23, 64, 57, 54, 54, 58, 49, 36, 65, 70, 64, 19, 43, 49, 50, 30, 31, 53, 44, 48, 53, 50, 27, 66, 55, 54, 33, 23, 51, 38, 41, 21, 43, 58, 49, 42, 66, 46, 64, 35, 63, 51, 29, 25, 50, 45, 37, 55, 42, 58, 22, 60, 21, 51, 32, 18, 34, 40]

# %%
import pandas as pd
# Crear un Dataframe de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    35
# 1    44
# 2    27
# 3    21
# 4    65

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("tabla de distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 45    18           1
# 17    19           2
# 30    20           1
# 5     21           4
# 43    22           1
# 26    23           2
# 31    24           1
# 42    25           1
# 34    26           1
# 14    27           2
# 41    29           1
# 10    30           3
# 7     31           3
# 19    32           2
# 39    33           1
# 23    34           2
# 21    35           2
# 36    36           1
# 12    37           3
# 25    38           2
# 46    40           1
# 22    41           2
# 15    42           2
# 3     43           4
# 13    44           2
# 20    45           2
# 40    46           1
# 37    48           1
# 4     49           4
# 8     50           3
# 2     51           5
# 32    52           1
# 27    53           2
# 1     54           6
# 24    55           2
# 38    57           1
# 9     58           3
# 35    59           1
# 44    60           1
# 16    61           2
# 29    62           1
# 18    63           2
# 0     64           6
# 6     65           3
# 11    66           3
# 33    68           1
# 28    70           2

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa
# 45    18           1           0.01
# 17    19           2           0.02
# 30    20           1           0.01
# 5     21           4           0.04
# 43    22           1           0.01
# 26    23           2           0.02
# 31    24           1           0.01
# 42    25           1           0.01
# 34    26           1           0.01
# 14    27           2           0.02
# 41    29           1           0.01
# 10    30           3           0.03
# 7     31           3           0.03
# 19    32           2           0.02
# 39    33           1           0.01
# 23    34           2           0.02
# 21    35           2           0.02
# 36    36           1           0.01
# 12    37           3           0.03
# 25    38           2           0.02
# 46    40           1           0.01
# 22    41           2           0.02
# 15    42           2           0.02
# 3     43           4           0.04
# 13    44           2           0.02
# 20    45           2           0.02
# 40    46           1           0.01
# 37    48           1           0.01
# 4     49           4           0.04
# 8     50           3           0.03
# 2     51           5           0.05
# 32    52           1           0.01
# 27    53           2           0.02
# 1     54           6           0.06
# 24    55           2           0.02
# 38    57           1           0.01
# 9     58           3           0.03
# 35    59           1           0.01
# 44    60           1           0.01
# 16    61           2           0.02
# 29    62           1           0.01
# 18    63           2           0.02
# 0     64           6           0.06
# 6     65           3           0.03
# 11    66           3           0.03
# 33    68           1           0.01
# 28    70           2           0.02

# %%
tabla_frecuencias['Frec Porcenual'] = tabla_frecuencias['Frecuencia']/100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec Porcenual
# 45    18           1           0.01             1.0
# 17    19           2           0.02             2.0
# 30    20           1           0.01             1.0
# 5     21           4           0.04             4.0
# 43    22           1           0.01             1.0
# 26    23           2           0.02             2.0
# 31    24           1           0.01             1.0
# 42    25           1           0.01             1.0
# 34    26           1           0.01             1.0
# 14    27           2           0.02             2.0
# 41    29           1           0.01             1.0
# 10    30           3           0.03             3.0
# 7     31           3           0.03             3.0
# 19    32           2           0.02             2.0
# 39    33           1           0.01             1.0
# 23    34           2           0.02             2.0
# 21    35           2           0.02             2.0
# 36    36           1           0.01             1.0
# 12    37           3           0.03             3.0
# 25    38           2           0.02             2.0
# 46    40           1           0.01             1.0
# 22    41           2           0.02             2.0
# 15    42           2           0.02             2.0
# 3     43           4           0.04             4.0
# 13    44           2           0.02             2.0
# 20    45           2           0.02             2.0
# 40    46           1           0.01             1.0
# 37    48           1           0.01             1.0
# 4     49           4           0.04             4.0
# 8     50           3           0.03             3.0
# 2     51           5           0.05             5.0
# 32    52           1           0.01             1.0
# 27    53           2           0.02             2.0
# 1     54           6           0.06             6.0
# 24    55           2           0.02             2.0
# 38    57           1           0.01             1.0
# 9     58           3           0.03             3.0
# 35    59           1           0.01             1.0
# 44    60           1           0.01             1.0
# 16    61           2           0.02             2.0
# 29    62           1           0.01             1.0
# 18    63           2           0.02             2.0
# 0     64           6           0.06             6.0
# 6     65           3           0.03             3.0
# 11    66           3           0.03             3.0
# 33    68           1           0.01             1.0
# 28    70           2           0.02             2.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec Porcenual  Frec Acumulada
# 45    18           1           0.01             1.0               1
# 17    19           2           0.02             2.0               3
# 30    20           1           0.01             1.0               4
# 5     21           4           0.04             4.0               8
# 43    22           1           0.01             1.0               9
# 26    23           2           0.02             2.0              11
# 31    24           1           0.01             1.0              12
# 42    25           1           0.01             1.0              13
# 34    26           1           0.01             1.0              14
# 14    27           2           0.02             2.0              16
# 41    29           1           0.01             1.0              17
# 10    30           3           0.03             3.0              20
# 7     31           3           0.03             3.0              23
# 19    32           2           0.02             2.0              25
# 39    33           1           0.01             1.0              26
# 23    34           2           0.02             2.0              28
# 21    35           2           0.02             2.0              30
# 36    36           1           0.01             1.0              31
# 12    37           3           0.03             3.0              34
# 25    38           2           0.02             2.0              36
# 46    40           1           0.01             1.0              37
# 22    41           2           0.02             2.0              39
# 15    42           2           0.02             2.0              41
# 3     43           4           0.04             4.0              45
# 13    44           2           0.02             2.0              47
# 20    45           2           0.02             2.0              49
# 40    46           1           0.01             1.0              50
# 37    48           1           0.01             1.0              51
# 4     49           4           0.04             4.0              55
# 8     50           3           0.03             3.0              58
# 2     51           5           0.05             5.0              63
# 32    52           1           0.01             1.0              64
# 27    53           2           0.02             2.0              66
# 1     54           6           0.06             6.0              72
# 24    55           2           0.02             2.0              74
# 38    57           1           0.01             1.0              75
# 9     58           3           0.03             3.0              78
# 35    59           1           0.01             1.0              79
# 44    60           1           0.01             1.0              80
# 16    61           2           0.02             2.0              82
# 29    62           1           0.01             1.0              83
# 18    63           2           0.02             2.0              85
# 0     64           6           0.06             6.0              91
# 6     65           3           0.03             3.0              94
# 11    66           3           0.03             3.0              97
# 33    68           1           0.01             1.0              98
# 28    70           2           0.02             2.0             100

# %%
# Importamos la libreria math de funciones matematicas
import math
# Volvemos a usar la lista edades
print(edades)
# Out:
# [35, 44, 27, 21, 65, 49, 64, 45, 32, 63, 64, 62, 20, 66, 43, 65, 21, 24, 31, 26, 41, 51, 37, 43, 38, 30, 54, 70, 61, 61, 54, 19, 64, 68, 37, 59, 54, 51, 52, 34, 31, 30, 23, 64, 57, 54, 54, 58, 49, 36, 65, 70, 64, 19, 43, 49, 50, 30, 31, 53, 44, 48, 53, 50, 27, 66, 55, 54, 33, 23, 51, 38, 41, 21, 43, 58, 49, 42, 66, 46, 64, 35, 63, 51, 29, 25, 50, 45, 37, 55, 42, 58, 22, 60, 21, 51, 32, 18, 34, 40]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad' : edades})
df
# Out:
#     Edad
# 0     35
# 1     44
# 2     27
# 3     21
# 4     65
# ..   ...
# 95    51
# 96    32
# 97    18
# 98    34
# 99    40
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(n))
print("Valor de n = ", n , " \nNumero de intervalos =", k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
# Crear la tabla de frecuencia

tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (47.714, 55.143]    24
# 1    (62.571, 70.0]    17
# 2  (17.947, 25.429]    13
# 3  (40.286, 47.714]    13
# 4  (25.429, 32.857]    12
# 5  (32.857, 40.286]    12
# 6  (55.143, 62.571]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    13
# 4  (25.429, 32.857]    12
# 5  (32.857, 40.286]    12
# 3  (40.286, 47.714]    13
# 0  (47.714, 55.143]    24
# 6  (55.143, 62.571]     9
# 1    (62.571, 70.0]    17

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Por Ac'] = tabla_frecuencia['Frec Porc'].cumsum()
# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 2  (17.947, 25.429]    13      0.13       13.0       13         0.13
# 4  (25.429, 32.857]    12      0.12       12.0       25         0.25
# 5  (32.857, 40.286]    12      0.12       12.0       37         0.37
# 3  (40.286, 47.714]    13      0.13       13.0       50         0.50
# 0  (47.714, 55.143]    24      0.24       24.0       74         0.74
# 6  (55.143, 62.571]     9      0.09        9.0       83         0.83
# 1    (62.571, 70.0]    17      0.17       17.0      100         1.00
#
#    Frec Por Ac
# 2         13.0
# 4         25.0
# 5         37.0
# 3         50.0
# 0         74.0
# 6         83.0
# 1        100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins = k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
