# %% [markdown]
# <a href="https://colab.research.google.com/github/diego-sc11/Probabilidad/blob/main/Unidad1/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### **Practica 2. Máximo, mínimo, Rango y dispersión de datos**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Diego Rodriguez Rochin

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#Generamos 100 numeros aleatoreos que representan la produccion en metros de tela en 100 dias
fabrica1 = []
for i in range(100):
  numero_aleatoreo = round( random.uniform(50, 100),2)
  fabrica1.append(numero_aleatoreo)
print(fabrica1)
print("*"*1000)
# Out:
# [69.38, 89.29, 74.67, 58.76, 79.68, 90.87, 51.82, 91.24, 84.71, 85.24, 63.53, 89.32, 92.88, 87.79, 58.62, 73.93, 72.21, 98.77, 57.92, 77.42, 67.27, 52.79, 66.17, 64.99, 85.72, 52.13, 70.22, 76.58, 63.97, 83.7, 79.82, 69.08, 60.49, 81.21, 58.25, 68.97, 95.61, 57.94, 62.19, 88.36, 74.13, 95.44, 99.62, 71.35, 84.1, 69.05, 84.03, 90.45, 96.41, 94.07, 68.24, 52.84, 94.64, 81.2, 67.55, 67.93, 53.25, 92.89, 95.06, 88.17, 81.62, 95.35, 54.13, 87.37, 74.72, 77.67, 67.56, 76.62, 58.96, 57.93, 65.83, 69.29, 73.4, 71.1, 60.15, 95.68, 95.93, 82.86, 83.66, 62.27, 62.22, 69.06, 58.55, 92.1, 58.16, 56.23, 71.72, 67.58, 81.9, 84.94, 78.96, 58.21, 64.51, 98.53, 81.45, 68.54, 53.11, 77.65, 95.25, 96.4]
# ****************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************

# %%
fabrica2 = []
for i in range(100):
  numero_aleatoreo = round( random.uniform(50, 100),2)
  fabrica2.append(numero_aleatoreo)
print(fabrica2)
# Out:
# [63.01, 80.56, 68.78, 82.51, 83.76, 70.28, 56.47, 52.26, 78.53, 51.87, 85.74, 86.45, 75.69, 60.86, 59.58, 95.23, 60.49, 77.87, 91.52, 74.84, 85.12, 63.21, 58.88, 50.19, 61.17, 58.77, 57.47, 85.85, 63.7, 86.76, 80.6, 75.73, 74.94, 59.07, 98.87, 50.02, 94.83, 60.04, 54.72, 73.55, 93.28, 91.88, 56.97, 72.39, 99.03, 99.76, 67.3, 68.26, 81.54, 84.79, 88.0, 92.36, 72.43, 65.78, 66.74, 54.16, 82.4, 73.1, 70.79, 59.74, 63.54, 77.04, 68.17, 83.7, 97.91, 72.36, 95.5, 60.41, 97.92, 85.46, 89.08, 90.55, 52.17, 74.13, 61.45, 74.1, 98.88, 80.75, 67.5, 76.31, 87.25, 54.67, 70.75, 71.27, 92.36, 92.73, 64.4, 85.62, 80.17, 72.89, 75.32, 80.53, 65.22, 78.66, 82.07, 78.26, 63.49, 84.2, 97.2, 68.81]

# %%
maximo1 = max(fabrica1)
minimo1 = max(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estadistica descriptiva de la fabrica 1 \n", "Media =",media1, "\nMediana =", mediana1, "\nModa =", moda1, "\nMaximo =", maximo1, "\n Minimo =", minimo1, "\nRango =",rango1)
print(f"desviacion estandar = {desviacion_estandar_fabrica1}")
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 75.411
# Mediana = 74.4
# Moda = 69.38
# Maximo = 99.62
#  Minimo = 99.62
# Rango = 0.0
# desviacion estandar = 13.821884966979143
